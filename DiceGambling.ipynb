# %%
import random

# %%
def roll():
    min_value = 1
    max_value = 6
    roll = random.randint(min_value, max_value)

    return roll

# %%
while True:
  players=input("Enter the number of players (2-4): ")
  if players.isdigit():
    players=int(players)
    if 2<=players<=4:
      break
    else:
      print("Must be between 2 - 4 players")
  else:
    print("Invalid, try again")

# %%
max_score=35
player_scores=[0 for _ in range(players)]

# %%
while max(player_scores)<max_score:
  for player_idx in range(players):
    print("\nplayer number",player_idx+1,"turn has started\n")
    print("your total score is:",player_scores[player_idx],"\n")
    current_score=0

    while True:
      should_roll=input("would you like to roll (y)? ")
      if should_roll.lower()!="y":
        break

      value=roll()
      if value==1:
        print("you rolled a 1! turn done!")
        current_score=0
        break
      else:
        current_score+=value
        print("you rolled a:",value)
      print("your score is:",current_score)

    player_scores[player_idx]+=current_score
    print("your total score is:",player_scores[player_idx])


max_score=max(player_scores)
winning_idx=player_scores.index(max_score)
print("player number",winning_idx+1,"is the winner with a score of:",max_score)
# Out:
# player number 1 turn has started
#
# your total score is: 0
#
# you rolled a: 2
# your score is: 2
# you rolled a: 5
# your score is: 7
# you rolled a: 6
# your score is: 13
# you rolled a 1! turn done!
# your total score is: 0
#
# player number 2 turn has started
#
# your total score is: 0
#
# you rolled a: 5
# your score is: 5
# you rolled a: 6
# your score is: 11
# you rolled a: 5
# your score is: 16
# you rolled a: 4
# your score is: 20
# you rolled a 1! turn done!
# your total score is: 0
#
# player number 1 turn has started
#
# your total score is: 0
#
# you rolled a: 5
# your score is: 5
# you rolled a: 5
# your score is: 10
# you rolled a: 5
# your score is: 15
# you rolled a: 6
# your score is: 21
# you rolled a: 5
# your score is: 26
# you rolled a: 6
# your score is: 32
# your total score is: 32
#
# player number 2 turn has started
#
# your total score is: 0
#
# you rolled a: 6
# your score is: 6
# you rolled a: 4
# your score is: 10
# you rolled a 1! turn done!
# your total score is: 0
#
# player number 1 turn has started
#
# your total score is: 32
#
# you rolled a: 3
# your score is: 3
# you rolled a: 4
# your score is: 7
# you rolled a: 4
# your score is: 11
# you rolled a: 5
# your score is: 16
# you rolled a: 5
# your score is: 21
# you rolled a: 3
# your score is: 24
# you rolled a: 6
# your score is: 30
# you rolled a 1! turn done!
# your total score is: 32
#
# player number 2 turn has started
#
# your total score is: 0
#
# you rolled a: 3
# your score is: 3
# you rolled a: 4
# your score is: 7
# you rolled a: 4
# your score is: 11
# you rolled a: 5
# your score is: 16
# you rolled a 1! turn done!
# your total score is: 0
#
# player number 1 turn has started
#
# your total score is: 32
#
# you rolled a: 2
# your score is: 2
# you rolled a: 3
# your score is: 5
# you rolled a: 4
# your score is: 9
# you rolled a: 5
# your score is: 14
# you rolled a: 2
# your score is: 16
# you rolled a: 6
# your score is: 22
# you rolled a: 5
# your score is: 27
# your total score is: 59
#
# player number 2 turn has started
#
# your total score is: 0
#
# you rolled a: 3
# your score is: 3
# you rolled a 1! turn done!
# your total score is: 0
# player number 1 is the winner with a score of: 59
